# 9.[Bowers & Wilkins Px7 S2e ](https://www.amazon.ca/Bowers-Wilkins-Over-Ear-Headphones-Model/dp/B0CH1LT84X/ref=sr_1_1?crid=2BH2353S3B35Y&dib=eyJ2IjoiMSJ9.gt1AdVVnyfUNyTrMmoJPNhf_2fNHHMOVuvl3Ha5S_mxBAPXWB-Usz5rMOFDK81N3hwHGSfq3DSAsd9Cf6CEAnHVJzzE1ZVCPcQDkLiOLGTy9djTqerwQdrxO_1up9sES39V6f82xCmskCeZ0jtzbyDFTYlu0rAIcUNRe5roc9aeRp98LfkI0TTZF25Sd2raq7rUIjohYMKY6WyO0FY5-6XrCepuRUMTzYhEfWEsDCH6R_GP_coFmPTSAkaTty12zksRcANkKDHJpGeswTD8sVlHdQCwwDMRykSGnJLqAaik.9NhQeKBOgEnxtyaT8lzfYC1jPJJaoTP3vtvLjhqRe6Q&dib_tag=se&keywords=Bowers+%26+Wilkins+PX7+Wireless+Headphones%3A&qid=1726429889&sprefix=bowers+%26+wilkins+px7+wireless+headphones+%2Caps%2C242&sr=8-1)
# 10.[Marshall Monitor II](https://www.amazon.ca/Marshall-Canceling-Over-Ear-Bluetooth-Headphone/dp/B084R2WVLX/ref=sr_1_2_sspa?crid=1BNMBU7L51J3T&dib=eyJ2IjoiMSJ9.luDiDJdfkJHnknGwNow5FCh12IyUuPAgU_rEpxeSY1zqcF7OavQB7VeRUUCuCJ4JnefQ685__OxkswZs-8dqsbY21HAVZ-0S-zxdu_9tb6Pi7iXRe0UMIoNw7aG4CUZXsTIf4aVp7y9oyTLDXfWNejo_nOu5wM2C6h1bPtcYupxLzmPMY5rNCwKBWZ1aHJRlW6FINzNKQm31j2OJ6aS70FPdpe_RvmyRJTHh9xkH3xc.MscVYY_8jt2AZ1eNCXIGf08aAWbXoyV_W-hL6xc9Y_E&dib_tag=se&keywords=Marshall+Monitor+II+A.N.C.+Wireless+Bluetooth+Headphones&qid=1726429956&sprefix=marshall+monitor+ii+a+n+c+wireless+bluetooth+headphones%2Caps%2C238&sr=8-2-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1)

# %% [markdown]
# ### 1.2 Background
# Beats by Dre is a leading brand in the tech industry, known for its audio products. With the rise of e-commerce, understanding consumer sentiment is crucial to improving customer experience and product development. This project focuses on analyzing customer reviews to gain insights into sentiment trends and provide recommendations for product enhancements.

# %% [markdown]
# #Section 2: Data Description

# %% [markdown]
# ###2.1 Data Sources
# - **Source**: The data consists of Amazon product reviews for all theproducts.
# - **Attributes**:
#     - `review_id`: Unique identifier for each review.
#     - `product_id`: Product-specific identifier.
#     - `title`: Title of the review.
#     - `author`: Name of the reviewer.
#     - `rating`: Numerical rating (1 to 5).
#     - `content`: The main text of the review.
#     - `timestamp`: Date when the review was posted.
#     - `profile_id`: Reviewer’s unique identifier.
#     - `is_verified`: Whether the reviewer purchased the product from Amazon.
#     - `helpful_count`: Number of people who found the review helpful.
#     - `product_attributes`: Additional product-specific information (e.g., color, model).

# %% [markdown]
# ###2.2 Data Collection
# - **Tools Used**: Web scraping tool, OxyLabs was used to collect reviews from Amazon.
# - **Challenges**:
#     - **Incomplete data**: Some reviews were missing fields like product attributes, which were handled in the data cleaning phase.

# %% [markdown]
# ###2.3 Data Cleaning
# **Key Points:**
# - **Handling Missing Values**: Filled missing values with the placeholder 'Unknown' for consistency.
# - **Duplicates**: No duplicate reviews.
# - **Standardizing Formats**: Converted review timestamps into a uniform datetime format.
# - **Content Length**: Added a column to store the number of characters in the content of each review .

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import os
import google.generativeai as genai
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import numpy as np
from textblob import TextBlob
import nltk
nltk.download('punkt')
import nltk
nltk.download('vader_lexicon')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
#  Loading the dataset

# %%
df = pd.read_csv('/content/merged_data.csv')
df.head()
# Out:
#         review_id  product_id  \
# 0  R20IRE5X6WY351  B085296FLT
# 1  R22UQLVXAO1YU6  B085296FLT
# 2   R9L9H16RFQHQY  B085296FLT
# 3  R1AGLOG6IH1XW0  B085296FLT
# 4  R2MF9YP1ULH0Z8  B085296FLT
#
#                                                title            author  \
# 0               5.0 out of 5 stars Great headphones!    Talia Calazans
# 1        5.0 out of 5 stars Stylish and Long-Lasting            Briana
# 2                   5.0 out of 5 stars Beats Studio3           Michael
# 3         5.0 out of 5 stars Great quality and price             SethB
# 4  5.0 out of 5 stars You can't beat Beats Studio...  Christopher Wood
#
#    rating                                            content  \
# 0       5  I love these headphones, and I wear them all t...
# 1       5  The Beats Studio3 Wireless Noise Cancelling Ov...
# 2       5  The Beats Studio3 is great headphones. I mainl...
# 3       5  I got these because my old pair finally broke ...
# ...

# %% [markdown]
# Checking for missing values and duplicates

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
duplicates = df.duplicated()

# Find duplicate rows
duplicates = df.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")
# Out:
# review_id               0
# product_id              0
# title                   0
# author                  0
# rating                  0
# content                 0
# timestamp               0
# profile_id              0
# is_verified             0
# helpful_count           0
# product_attributes    169
# dtype: int64
# Number of duplicate rows: 0

# %% [markdown]
# There are only some missing values in product_attributes and no duplicate rows.

# %% [markdown]
# Filling missing values with a placeholder (Unknown)

# %%
df = df.fillna("Unknown")
df.isnull().sum()
# Out:
# review_id             0
# product_id            0
# title                 0
# author                0
# rating                0
# content               0
# timestamp             0
# profile_id            0
# is_verified           0
# helpful_count         0
# product_attributes    0
# dtype: int64

# %% [markdown]
# Adding 2 columns using ASIN (product_id), Brand name and product name(full name of the product)

# %%
product_id_mapping = {
    'B085296FLT': {'brand': 'Beats', 'product': 'Beats Studio3'},
    'B0863TXGM3': {'brand': 'Sony', 'product': 'Sony WH-1000XM4 Wireless'},
    'B091FZK6VB': {'brand': 'JBL', 'product': 'JBL Live 660NC Wireless'},
    'B0B6GHW1SX': {'brand': 'Sennheiser', 'product': 'Sennheiser Momentum 4'},
    'B08FCGH2RL': {'brand': 'Skullcandy', 'product': 'Skullcandy Crusher Evo Wireless '},
    'B0CGTL9GFD': {'brand': 'Edifier', 'product': 'Edifier WH700NB Wireless'},
    'B09BYFHL25': {'brand': 'Audio-Technica', 'product': 'Audio-Technica ATH-M50xBT2 Wireless '},
    'B0CH1LT84X': {'brand': 'Bowers', 'product': 'Bowers & Wilkins Px7 S2e'},
    'B084R2WVLX': {'brand': 'Marshall', 'product': 'Marshall Monitor II Active '},
    'B09HL9MQ64': {'brand': 'Bose', 'product': 'Bose QuietComfort 45 Wireless'}
}

# Function to get brand name and product name using ASIN
def get_brand_product(asin):
    if asin in product_id_mapping:
        return product_id_mapping[asin]['brand'], product_id_mapping[asin]['product']
    else:
        return 'Unknown Brand', 'Unknown Product'

# Apply the function to the ASIN column and create new columns
df['brand_name'], df['product_name'] = zip(*df['product_id'].apply(get_brand_product))

df.head()
# Out:
#         review_id  product_id  \
# 0  R20IRE5X6WY351  B085296FLT
# 1  R22UQLVXAO1YU6  B085296FLT
# 2   R9L9H16RFQHQY  B085296FLT
# 3  R1AGLOG6IH1XW0  B085296FLT
# 4  R2MF9YP1ULH0Z8  B085296FLT
#
#                                                title            author  \
# 0               5.0 out of 5 stars Great headphones!    Talia Calazans
# 1        5.0 out of 5 stars Stylish and Long-Lasting            Briana
# 2                   5.0 out of 5 stars Beats Studio3           Michael
# 3         5.0 out of 5 stars Great quality and price             SethB
# 4  5.0 out of 5 stars You can't beat Beats Studio...  Christopher Wood
#
#    rating                                            content  \
# 0       5  I love these headphones, and I wear them all t...
# 1       5  The Beats Studio3 Wireless Noise Cancelling Ov...
# 2       5  The Beats Studio3 is great headphones. I mainl...
# 3       5  I got these because my old pair finally broke ...
# ...

# %% [markdown]
# Adding a column for date (extracting from timestamp)

# %%
# Function to extract the date from the timestamp
def extract_date(timestamp):
    # Split the string and take the last part (the date)
    try:
        date_part = timestamp.split("Reviewed in the United States ")[-1]
        return pd.to_datetime(date_part, format='%B %d, %Y', errors='coerce')
    except Exception as e:
        return pd.NaT  # Return Not-a-Time for any errors

# Create a new column 'date' to hold the extracted dates
df['date'] = df['timestamp'].apply(extract_date)
df.head()
# Out:
#         review_id  product_id  \
# 0  R20IRE5X6WY351  B085296FLT
# 1  R22UQLVXAO1YU6  B085296FLT
# 2   R9L9H16RFQHQY  B085296FLT
# 3  R1AGLOG6IH1XW0  B085296FLT
# 4  R2MF9YP1ULH0Z8  B085296FLT
#
#                                                title            author  \
# 0               5.0 out of 5 stars Great headphones!    Talia Calazans
# 1        5.0 out of 5 stars Stylish and Long-Lasting            Briana
# 2                   5.0 out of 5 stars Beats Studio3           Michael
# 3         5.0 out of 5 stars Great quality and price             SethB
# 4  5.0 out of 5 stars You can't beat Beats Studio...  Christopher Wood
#
#    rating                                            content  \
# 0       5  I love these headphones, and I wear them all t...
# 1       5  The Beats Studio3 Wireless Noise Cancelling Ov...
# 2       5  The Beats Studio3 is great headphones. I mainl...
# 3       5  I got these because my old pair finally broke ...
# ...

# %% [markdown]
# Adding a column of content length, which is the length of the review.

# %%
# Calculate the length of content
df['content_length'] = df['content'].apply(len)

# %% [markdown]
# #Section 3: EDA

# %% [markdown]
# ###3.1 Data Overview
# **Key Points:**
# - **Mode Summary:**
#  The most frequent values in the dataset indicate that the typical review is authored by "Amazon Customer," with a perfect 5-star rating and a short title like "Excellent" or similar.
#
# - **Variance in Numeric Columns** The variance for helpful_count and content_length is very large, indicating that helpfulness and review length vary widely.
# - **Median Values:** The median rating is 5.0, showing that most customers gave the highest possible rating. The median helpful_count is 0.0, meaning most reviews have not received any upvotes. The median review length is 398.5 characters.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   review_id           976 non-null    object
#  1   product_id          976 non-null    object
#  2   title               976 non-null    object
#  3   author              976 non-null    object
#  4   rating              976 non-null    int64
#  5   content             976 non-null    object
#  6   timestamp           976 non-null    object
#  7   profile_id          976 non-null    object
#  8   is_verified         976 non-null    bool
#  9   helpful_count       976 non-null    int64
#  10  product_attributes  976 non-null    object
#  11  brand_name          976 non-null    object
#  12  product_name        976 non-null    object
#  13  date                976 non-null    datetime64[ns]
#  14  content_length      976 non-null    int64
# ...

# %% [markdown]
# We have 1 boolean, 3 integer, 1 date and 10 object columns.

# %%
df.shape
# Out:
# (976, 15)

# %% [markdown]
# A total of 15 columns and 976 rows of data.

# %%
# Calculate mode
print("\nMode for each column:")
print(df.mode().iloc[0])  # Mode might return multiple rows, using iloc[0] for the first mode

# Calculate variance (only for numeric columns)
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
print("\nVariance for numeric columns:")
print(df[numeric_cols].var())

# Calculate median (only for numeric columns)
print("\nMedian for numeric columns:")
print(df[numeric_cols].median())
# Out:
# Mode for each column:
# review_id                                              R107HSPMJ4E47N
# product_id                                                 B084R2WVLX
# title                                    5.0 out of 5 stars Excellent
# author                                                Amazon Customer
# rating                                                            5.0
# content                                                       Awesome
# timestamp             Reviewed in the United States September 5, 2024
# profile_id                               AE23O75IIZVYP34WJST2EBUB4KXA
# is_verified                                                      True
# helpful_count                                                     0.0
# product_attributes                                            Unknown
# brand_name                                             Audio-Technica
# product_name                     Audio-Technica ATH-M50xBT2 Wireless
# ...

# %% [markdown]
# ### 3.2 Visualizations and Descriptive Statistics
# **Key Points:**
#
# - **Distribution of Ratings:**
#   The histogram of ratings indicates a clear peak at **5 stars**, suggesting that most reviews are overwhelmingly positive, with a significant number of reviews also rating **4 stars**.
#
# - **Ratings Comparison Across Products:**
#   The box plot comparing ratings across various products highlights that **Beats Studio3** has a lower percentage of **1-star** and **2-star** ratings. In contrast, competitor brands like **Sony**, **JBL**, and **Skullcandy** predominantly receive **4-star** and **5-star** ratings.
#
# - **Review Length vs. Rating:**
#   The scatter plot visualizes the relationship between review length and rating, indicating a **negative correlation** of **-0.107** with a p-value of **0.001**. This suggests that slightly longer reviews tend to receive lower ratings, although the relationship is very weak.
#
# - **Helpful Count vs. Review Content Length:**
#   A scatter plot of helpful count against review content length helps to visualize the correlation. This could reveal trends in how review length impacts perceived helpfulness.
#
# - **Helpful Count vs. Rating:**
#   Another scatter plot illustrates the relationship between helpful counts and ratings. This provides insight into how helpfulness is distributed across different rating categories.
#
# - **Average Rating by Product and Verification Status:**
#   The heatmap displaying average ratings based on product and verification status shows that most reviews were verified, with exceptions primarily for **Bowers** products.
#
# - **Total Helpful Count by Rating:**
#   A bar plot reveals that **5-star** and **2-star** ratings received the highest helpful counts, indicating that even lower-rated reviews can be perceived as helpful.
#
# - **Count of Reviews for Each Rating:**
#   The bar plot of review counts shows a predominance of **5-star** ratings, while **2-star** reviews are significantly fewer. Despite their lower frequency, **2-star** reviews had a surprisingly higher helpful count, highlighting the complexity of user perceptions.

# %%
# Create a figure with 1 row and 2 columns
fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Plotting the histogram of ratings
sns.histplot(df['rating'], bins=5, kde=True, color='blue', ax=axs[0])
axs[0].set_title('Distribution of Ratings for All Products')
axs[0].set_xlabel('Rating')
axs[0].set_ylabel('Frequency')
axs[0].set_xlim(0.5, 5.5)  # Set x-axis limits to range from 1 to 5
axs[0].set_xticks(range(1, 6))  # Set x-ticks to show whole numbers
axs[0].grid(True)

# Creating a stacked bar chart for each product divided by rating
# Create a count of ratings per product
rating_counts = df.groupby(['product_name', 'rating']).size().unstack(fill_value=0)

# Plotting the stacked bar chart
rating_counts.plot(kind='bar', stacked=True, ax=axs[1])
axs[1].set_title('Stacked Bar Chart of Ratings by Product')
axs[1].set_xlabel('Product')
axs[1].set_ylabel('Count of Ratings')
axs[1].set_xticks(range(len(rating_counts.index)))  # Adjust x-ticks for products
axs[1].set_xticklabels(rating_counts.index, rotation=45, ha='right')

# Customize the tick label for "Beats"
for label in axs[1].get_xticklabels():
    if label.get_text() == 'Beats Studio3':
        label.set_color('red')
        label.set_fontweight('bold')

axs[1].legend(title='Rating')
axs[1].grid(True)

# Show both plots
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# The Distribution of Ratings shows a clear peak at 5 stars , indicating that most reviews are 5,4 stars.
#
# The Stacked Bar Chart reveals that Beats Studio3 has a lower percentage of 1-star and 2-star ratings But Competitor brands like Sony, JBL, and Skullcandy also have mostly 4,5 ratings.

# %%
# Set the style for plots
sns.set(style="whitegrid")

## 1. Box Plot: Ratings Comparison Across All Products, Highlighting Beats

plt.figure(figsize=(12,8))
# Use a custom palette where Beats gets a distinct color
#palette = ['red' if product == 'Beats Studio3' else 'lightblue' for product in df['product_name']]
sns.boxplot(x='product_name', y='rating', data=df)
plt.xticks(rotation=45, ha='right')
plt.title('Ratings Comparison for Each Product (Beats Highlighted)')
plt.ylabel('Rating')
plt.xlabel('Product Name')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# The boxplot gives as a clearer spread of ratings for each product.

# %%
# Plotting review length vs. rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['content_length'], y=df['rating'], alpha=0.6, color='purple')
plt.title('Scatter Plot of Review Length vs. Rating')
plt.xlabel('Review Length')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# Adding comments:
# This scatter plot helps us identify if longer reviews tend to give more positive or negative ratings.

# %% [markdown]
# This scatter plot helps us identify if longer reviews tend to give more positive or negative ratings. There might be significant relationship here so checking using Pearson correlation.

# %%
# Calculate the Pearson correlation
correlation, p_value = pearsonr(df['content_length'], df['rating'])

# Print the correlation coefficient and p-value
print(f'Pearson correlation coefficient: {correlation:.3f}')
print(f'P-value: {p_value:.3f}')

# Determine the relationship and significance
if p_value < 0.05:
    significance = "statistically significant"
else:
    significance = "not statistically significant"

if correlation > 0:
    relationship = "positive"
elif correlation < 0:
    relationship = "negative"
else:
    relationship = "no"

print(f'The relationship between review length and rating is {relationship} and is {significance}.')
# Out:
# Pearson correlation coefficient: -0.107
# P-value: 0.001
# The relationship between review length and rating is negative and is statistically significant.

# %% [markdown]
# The value of -0.107 suggests a very weak negative relationship. This means that, on average, slightly longer reviews tend to have slightly lower ratings, but the relationship is not strong.
#
# The p-value of 0.001 is significantly less than 0.05, indicating that the observed correlation is statistically significant.
#
# Overall, the results suggest that there's a very weak tendency for longer reviews to have slightly lower ratings.

# %% [markdown]
# **Scatter Plot of Helpful Count Against Length of Content**
#
# This plot will help us visualize if there’s any correlation between the length of the review content and the helpful count.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='content_length', y='helpful_count', data=df, color='blue', alpha=0.6)
plt.title('Helpful Count vs Length of Review Content')
plt.xlabel('Length of Review Content')
plt.ylabel('Helpful Count')
plt.show()

# %% [markdown]
# **Scatter Plot of Rating vs Helpful Count**
#
# This plot shows how helpful counts relate to the ratings given.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='rating', y='helpful_count', data=df, color='blue', alpha=0.6)
plt.title('Rating vs Helpful Count')
plt.xlabel('Rating')
plt.ylabel('Helpful Count')
plt.show()

# %%
avg_rating_verification = df.groupby(['product_name', 'is_verified',])['rating'].mean().unstack()

plt.figure(figsize=(10, 6))
sns.heatmap(avg_rating_verification, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Average Rating by Product and Verification Status')
plt.xlabel('Verified Status')
plt.ylabel('Product Name')
plt.show()

# %% [markdown]
# This heatmap shows the average rating for each product based on whether the review was verified or not. This show that all the reviews were verified except for some for Bowers.

# %%
# Group by rating and calculate the sum of helpful counts
rating_helpful_count = df.groupby('rating')['helpful_count'].sum().reset_index()

# Plotting
plt.figure(figsize=(10, 6))

# Create a bar plot
sns.barplot(x='rating', y='helpful_count', data=rating_helpful_count, color='blue')

# Add labels and title
plt.title('Total Helpful Count by Rating')
plt.xlabel('Rating')
plt.ylabel('Total Helpful Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# We see that 5 and 2 rating was most helpful.

# %%
# Count the number of occurrences of each rating
rating_counts = df['rating'].value_counts().sort_index().reset_index()
rating_counts.columns = ['rating', 'count']  # Rename columns for clarity

# Plotting
plt.figure(figsize=(10, 6))

# Create a bar plot for rating counts
sns.barplot(x='rating', y='count', data=rating_counts, color='lightblue')

# Add labels and title
plt.title('Count of Reviews for Each Rating')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# But this shows that most rating were 5 stars and 2 star reviews are ver less but still had a more helpful count.

# %% [markdown]
# ### 3.3 Correlation Analysis
#
# **Key Insights from Correlation and P-Value Matrices**
#
# - **Correlation between Content Length and Helpful Count**
# A positive correlation of **0.37** exists between `content_length` and `helpful_count`. This indicates that longer reviews tend to receive more helpful votes, though this correlation is moderate.
#
# - **Weak Correlations with Rating**
# The `rating` variable shows weak correlations with both `helpful_count` (-0.05) and `content_length` (-0.11). This suggests that the length of a review and how helpful it is perceived have minimal influence on the product's rating.
#
# - **P-Values Indicate Significant Relationships**
# Based on the P-Value Matrix, the relationships between `content_length` and `helpful_count`, as well as `helpful_count` and `rating`, are statistically significant with p-values close to **0.00**, which are well below the significance threshold of **0.05**.
#
# - **Statistically Insignificant Correlations for Rating**
# The correlation between `rating` and both `content_length` and `helpful_count` is not statistically significant, as indicated by the p-value of **0.11**. This suggests that variations in review length or helpful votes do not significantly impact the product ratings.

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# Initialize a matrix for p-values
p_value_matrix = np.zeros(correlation_matrix.shape)

# Calculate p-values for each pair
for i in range(len(correlation_matrix.columns)):
    for j in range(len(correlation_matrix.columns)):
        if i != j:
            _, p_value = pearsonr(numeric_df.iloc[:, i], numeric_df.iloc[:, j])
            p_value_matrix[i, j] = p_value
        else:
            p_value_matrix[i, j] = np.nan  # Set diagonal to NaN (no correlation)

# Convert p-value matrix to a DataFrame for better visualization
p_value_df = pd.DataFrame(p_value_matrix, index=correlation_matrix.columns, columns=correlation_matrix.columns)

# Set up the matplotlib figure for correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar=True)
plt.title('Correlation Matrix')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()

# Set up the matplotlib figure for p-value heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_value_df, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar=True, mask=np.isnan(p_value_df))
plt.title('P-Value Matrix')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()

# Interpretation of significance
significance_threshold = 0.05
significant_correlations = p_value_df < significance_threshold
print("Significant correlations (p < 0.05):")
print(significant_correlations)
# Out:
# Significant correlations (p < 0.05):
#                 rating  helpful_count  content_length
# rating           False          False            True
# helpful_count    False          False            True
# content_length    True           True           False

# %% [markdown]
# ### 3.4 Summary of Key Patterns, Trends, and Anomalies
#
# - **Dominant Positivity:**
#   The overwhelming positivity in the dataset is the dominant trend, with most reviews scoring **5 stars**.
#
# - **Weak Negative Correlation:**
#   There is a weak negative correlation between review length and rating, which might indicate that more detailed reviews tend to highlight more critical feedback.
#
# - **Impact of Verified Reviews:**
#   Verified reviews seem to have a notable impact on ratings, with verified reviews often receiving higher scores.
#
# - **Helpful 2-Star Reviews:**
#   Despite their low count, **2-star reviews** are more helpful to customers, possibly due to their ability to effectively highlight product flaws or shortcomings.

# %% [markdown]
# #Section 4: Sentiment Analysis using TextBlob

# %% [markdown]
# **Key Points:**
#
# - Majority of reviews are **Positive**.
#
# - Most reviews have polarity between **0 and 0.5**, peaking around **0.25**, suggesting moderately positive reviews.
# - Strong positive sentiment with a significant peak near **1.0**, indicating that many reviews are overwhelmingly positive.
# - Very few reviews show negative or neutral sentiment based on both analyses.
#
# **Analysis by Product**
# - There are very few neutral and negative reviews overall.
# - **Beats** has around **20%** neutral reviews, while the rest are predominantly **positive**.

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='pastel')
plt.title('Sentiment Analysis of Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-109-5c080a2b05b5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='pastel')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# This is the Overall distribution.

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# TextBlob Sentiment Analysis
def get_textblob_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity, blob.sentiment.subjectivity

# Applying TextBlob on reviews
df['polarity'], df['subjectivity'] = zip(*df['content'].apply(get_textblob_sentiment))

# VADER Sentiment Analysis
sia = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    return sia.polarity_scores(text)

# Applying VADER on reviews
df['vader_sentiment'] = df['content'].apply(get_vader_sentiment)
df['vader_compound'] = df['vader_sentiment'].apply(lambda x: x['compound'])

# Visualizing sentiment distribution using histograms
plt.figure(figsize=(12, 6))

# Polarity distribution from TextBlob
plt.subplot(1, 2, 1)
plt.hist(df['polarity'], bins=20, color='blue', alpha=0.7)
plt.title('TextBlob Sentiment Polarity Distribution')
plt.xlabel('Polarity')
plt.ylabel('Frequency')

# Compound score distribution from VADER
plt.subplot(1, 2, 2)
plt.hist(df['vader_compound'], bins=20, color='green', alpha=0.7)
plt.title('VADER Sentiment Compound Score Distribution')
plt.xlabel('Compound Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **TextBlob Sentiment Polarity Distribution**
# - Most of the reviews have a polarity between **0 and 0.5**, with the highest concentration around **0.25**. This suggests that the majority of the reviews are positive, but not overwhelmingly so.
# - There are fewer negative reviews, as seen in the low frequency of polarity values below **0**.
#
# **VADER Sentiment Compound Score Distribution**
# - The compound score shows a strong positive sentiment, with a significant peak near **1.0**, indicating that many reviews are overwhelmingly positive.
# - There are very few reviews with negative or neutral scores, as seen in the low frequencies for compound scores below **0**.

# %%
def get_sentiment(review):
    analysis = TextBlob(review)
    # Classify the sentiment
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment'] = df['content'].apply(get_sentiment)
sentiment_counts = df['sentiment'].value_counts()
print(sentiment_counts)
sentiment_summary = df.groupby(['product_name', 'sentiment']).size().unstack(fill_value=0)

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a grouped bar chart
sentiment_summary.plot(kind='bar', stacked=False, color=['lightgreen', 'salmon', 'lightgrey'], edgecolor='black')

plt.title('Sentiment Analysis by Product')
plt.xlabel('Product Name')
plt.ylabel('Count of Sentiments')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()
# Out:
# sentiment
# Positive    875
# Neutral      51
# Negative     50
# Name: count, dtype: int64

# %% [markdown]
# We see that there are very little neutral and negative reviews for every product. But we can see that there are around 20% reviews for beats which are neutral.

# %%
# Filter for Beats Studio3 reviews
beats_df = df[df['product_name'] == 'Beats Studio3']

# Filter for competitor reviews (all other products)
competitors_df = df[df['product_name'] != 'Beats Studio3']

# Filter for positive and negative reviews for Beats and competitors
beats_positive_reviews = " ".join(beats_df[beats_df['sentiment'] == 'Positive']['content'])
beats_negative_reviews = " ".join(beats_df[beats_df['sentiment'] == 'Negative']['content'])
competitors_positive_reviews = " ".join(competitors_df[competitors_df['sentiment'] == 'Positive']['content'])
competitors_negative_reviews = " ".join(competitors_df[competitors_df['sentiment'] == 'Negative']['content'])

# Function to generate and display word clouds in a 2-in-1 layout
def generate_wordclouds(text1, title1, text2, title2):
    plt.figure(figsize=(15, 7))

    # Word cloud for the first text
    plt.subplot(1, 2, 1)
    wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(text1)
    plt.imshow(wordcloud1, interpolation='bilinear')
    plt.axis('off')
    plt.title(title1)

    # Word cloud for the second text
    plt.subplot(1, 2, 2)
    wordcloud2 = WordCloud(width=800, height=400, background_color='white').generate(text2)
    plt.imshow(wordcloud2, interpolation='bilinear')
    plt.axis('off')
    plt.title(title2)

    plt.tight_layout()
    plt.show()

# Generate word clouds for positive reviews
generate_wordclouds(beats_positive_reviews, "Beats Studio3 Positive Reviews",
                     competitors_positive_reviews, "Competitors Positive Reviews")

# Generate word clouds for negative reviews
generate_wordclouds(beats_negative_reviews, "Beats Studio3 Negative Reviews",
                     competitors_negative_reviews, "Competitors Negative Reviews")

# %% [markdown]
# **Word Cloud Summary**
#
# - Both **Beats** and its competitors received positive reviews for **sound quality**, **comfort**, and **battery life**.
# - **Beats** faced some criticism for **build quality** and **noise cancellation** issues.
# - Competitors were praised for their **sound quality** and **comfort**, but were also criticized for **price** and **build quality**.

# %% [markdown]
# #Section 5: AI-Generated Insights
# Gemini AI was utilized to analyze customer reviewss. The analysis focused on identifying common themes, points of dissatisfaction, and customer suggestions for product improvements.

# %% [markdown]
# **Key Insights**
#
# The analysis produced several key insights from the reviews, summarized below:
#
# **Common Themes in Beats Studio3 Reviews:**
#
# **Positive Themes:**
# - **Sound Quality**: Praised for clarity and strong bass response.
# - **Comfort**: Soft ear cushions and adjustable headband received positive feedback.
# - **Noise Cancellation**: Generally effective, especially for blocking ambient noise.
# - **Battery Life**: Long battery life highlighted as a significant advantage.
# - **Build Quality**: Generally perceived as durable and well-constructed.
# - **Style**: Sleek design and color options favored by many.
# - **Value for Money**: Positive reviews on price, especially during sales.
#
# **Negative Themes:**
# - **Noise Cancellation**: Some users found it lacking for higher frequency sounds.
# - **Touch Controls**: Often criticized for being unreliable.
# - **Mic Quality**: Mixed feedback regarding background noise pickup.
# - **Fit**: Complaints about comfort for users with larger heads or ears.
#
# **Points of Dissatisfaction Compared to Competitors:**
# Users expressed concerns regarding build quality and functionality compared to competitors like Sony WH-1000XM4 and Bose QuietComfort.
#
# **Customer Suggestions for Product Improvements:**
# - Enhance noise cancellation technology for better performance against voices and louder noises.
# - Improve build quality and use more durable materials.
# - Refine sound quality to address issues with muddy mids and bass response.
# - Transition to USB-C charging for better durability and compatibility.
# - Redesign the carrying case for improved portability.

# %% [markdown]
# **Model Setup**

# %%
api_key = "Insert"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key, prompt_message):
    genai.configure(api_key=api_key)

    # Define generation configuration directly
    generation_config = {
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 64,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config=generation_config,
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %% [markdown]
# **Prompt 1: Identify Common Themes or Topics in Reviews**

# %%
# Define the prompt message for identifying common themes
prompt_message_1 = (
    "Analyze the following product reviews and identify the common themes or topics discussed:\\n\\n"
)

# Select all reviews' content
all_reviews = df['content'].tolist()

# Call the analyze_reviews function
common_themes = analyze_reviews(all_reviews, api_key, prompt_message_1)

# Display the response
print("Common Themes or Topics in Reviews:")
print(common_themes)
# Out:
# Common Themes or Topics in Reviews:
# ## Common Themes in Beats Studio3 Wireless Noise Cancelling Over-Ear Headphones Reviews:
#
# The reviews highlight various aspects of the Beats Studio3 headphones, revealing both positive and negative experiences. Here's a breakdown of common themes:
#
# **Positive:**
#
# * **Sound Quality:** Many reviewers praise the overall sound quality, particularly the bass and clarity. Some mention the seamless integration with Apple devices.
# * **Comfort:**  Reviewers consistently comment on the comfortable fit,  lightweight design, and plush ear cushions.
# * **Noise Cancellation:**  While some find it effective for blocking out background hums and airplane noise, others note it struggles with voices and other louder sounds.
# * **Battery Life:**  The battery life is generally well-received, with most users reporting it lasts for days with moderate use.
# * **Build Quality:**  The premium materials and sturdy construction are frequently mentioned.
# ...

# %% [markdown]
# **Prompt 2: Identify Points of Dissatisfaction for Beats vs Competitors**

# %%
prompt_message_3 = (
    "Analyze the following product reviews and identify the common points of dissatisfaction among customers for Beats Studio3 and its competitors:\n\n"
)

# Select relevant negative reviews for Beats and competitors
dissatisfaction_reviews = df[df['sentiment'] == 'Negative']['content'].tolist()

# Call the analyze_reviews function
dissatisfaction_points = analyze_reviews(dissatisfaction_reviews, api_key, prompt_message_3)

# Display the response
print("\nCommon Points of Dissatisfaction for Beats vs Competitors:")
print(dissatisfaction_points)
# Out:
# Common Points of Dissatisfaction for Beats vs Competitors:
# ## Common Points of Dissatisfaction for Beats Studio3 and Competitors:
#
# **Refurbished Products:**
#
# * **Functionality issues:** Many reviews highlight refurbished headphones arriving broken or malfunctioning, failing to charge, or losing power prematurely.
# * **Unhygienic condition:** Some refurbished headphones came with strong, unpleasant odors, making them unusable.
# * **Lack of quality control:** Customers express frustration with the lack of thorough testing and refurbishment before reselling, leading to disappointment and wasted time.
#
# **Sound Quality & Features:**
#
# * **Noise cancellation:** Some headphones were criticized for their noise cancellation performance, with some finding it ineffective in certain environments or causing pressure discomfort.
# * **Bass quality:** While some praised the bass, others found it overly pronounced or lacking in quality.
# ...

# %% [markdown]
# **Prompt 3: Identify Recurring Themes in Negative Reviews for Beats vs Competitors**

# %%
prompt_message_5 = (
    "Analyze the following product reviews and identify recurring themes in negative feedback for Beats Studio3 and its competitors:\n\n"
)

# Filter only negative reviews for both Beats and competitors
negative_reviews = df[df['sentiment'] == 'Negative']['content'].tolist()

# Call the analyze_reviews function
negative_themes = analyze_reviews(negative_reviews, api_key, prompt_message_5)

# Display the response
print("\nRecurring Themes in Negative Reviews for Beats vs Competitors:")
print(negative_themes)
# Out:
# Recurring Themes in Negative Reviews for Beats vs Competitors:
# ## Recurring Themes in Negative Feedback for Beats Studio3 and Competitors:
#
# This analysis focuses on negative feedback across different headphone brands, highlighting common issues:
#
# **1. Durability and Longevity:**
#
# * **Premature Breakage:** Many users report headphones breaking or malfunctioning within a year or two, often just outside the warranty period. This applies across brands like Beats, Bose, Sennheiser, and Marshall.
# * **Ear Pads Deteriorating:** Worn-out ear pads seem to be a frequent issue, especially after prolonged use.
# * **Adjusting Mechanisms Breaking:**  Some users reported issues with headband or earcup adjustments breaking, especially on Beats.
#
# **2. Refurbished Product Issues:**
#
# * **Functionality Issues:** Refurbished products are often reported as not properly refurbished or tested, leading to broken headphones upon arrival.
# ...

# %% [markdown]
# **Prompt 4: Extract Customer Suggestions for Product Improvements for Beats Studio3**

# %%
# Define the prompt message for extracting customer suggestions
prompt_message_4 = (
    "Analyze the following product reviews for 'Beats' and extract specific suggestions or recommendations "
    "that customers have made for improving the product:\n\n"
)

# Filter reviews for the product "Beats"
beats_reviews = df[df['product_name'] == 'Beats Studio3']['content'].tolist()

# Combine the reviews into a formatted string
formatted_beats_reviews = "\n\n".join(beats_reviews)

# Construct the full prompt by appending the reviews to the message
full_prompt_4 = prompt_message_4 + formatted_beats_reviews

# Call the analyze_reviews function with the specific reviews for "Beats"
customer_suggestions = analyze_reviews(beats_reviews, api_key, full_prompt_4)

# Display the response
print("Customer Suggestions for Product Improvements (Beats):")
print(customer_suggestions)
# Out:
# Customer Suggestions for Product Improvements (Beats):
# ## Beats Studio3 Wireless Noise Cancelling Over-Ear Headphones: Customer Feedback & Recommendations
#
# Here's an analysis of the customer reviews and suggestions for improvement:
#
# **Positive Aspects:**
#
# * **Sound Quality:**  Many customers praise the sound quality, particularly the bass response. Some even consider it "crystal clear" and "amazing."
# * **Comfort:**  Reviewers consistently mention the comfort of the over-ear design and soft earcups, allowing for long listening sessions.
# * **Noise Cancellation:**  While some find it lacking in canceling voices, customers generally appreciate the noise cancellation for blocking out background hums, making them effective for use on planes and in noisy environments.
# * **Battery Life:**  The battery life is consistently praised, with many reporting days of use on a single charge.
# ...

# %% [markdown]
# #Section 6: Comparative Analysis
# *Note: Comparision of sentiments is done in section 4*

# %% [markdown]
# # SWOT Analysis for Beats by Dre (based on above Sections)
#
# | **Category**    | **Description**                                                                                                                                           |
# |------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Strengths**    | - **Brand Recognition**: Strong brand image and recognition, particularly among younger consumers and celebrities.                                        |
# |                  | - **Sound Quality**: Generally positive reviews regarding sound quality, particularly for bass-heavy genres.                                            |                                                                                       |
# |                  | - **Integration**: Seamless compatibility with Apple devices, enhancing user experience for existing Apple customers.                                    |
# | **Weaknesses**   | - **Build Quality:** Some criticize the build quality, particularly the folding mechanism, the cheap feel of materials, and the lack of cushioning on the headband.  consumers.                                                |
# |                  | - **Noise Cancellation**: Mixed reviews about the effectiveness of noise cancellation, especially in comparison to competitors like Sony and Bose.        |
# |                  | - **Touch Controls**: Frustration among users regarding the reliability of touch controls.                                                               |
# | **Opportunities**| - **Product Innovation**: Potential to improve noise cancellation and expand feature set (e.g., customizable sound profiles).                            |
# |                  | - **Market Expansion**: Opportunities to capture markets outside the US, particularly in Asia and Europe, where demand for high-quality audio products is growing. |
# |                  | - **Sustainability**: Incorporating eco-friendly materials and practices could appeal to environmentally conscious consumers.                             |
# | **Threats**      | - **Intense Competition**: Competing brands such as Sony and Bose continually innovate, making it crucial for Beats to keep pace.                      |
# |                  | - **Changing Consumer Preferences**: A shift in consumer preferences towards budget-friendly or high-fidelity options may impact sales.                  |
# |                  |

# %% [markdown]
# # Section 7: Strategic Recommendations
#
# ## Product Improvements
# Based on the analysis, the following specific product improvements are suggested for Beats Studio3:
# - **Enhance Noise Cancellation**: Invest in more advanced noise cancellation technology to effectively block out a wider range of sounds, including voices and louder noises.
# - **Improve Build Quality**: Use higher quality materials, improve the folding mechanism, and add more cushioning to the headband for greater comfort and durability.
# - **Refine Sound Profile**: Address reported issues with muddy mids and underwhelming bass, potentially offering an EQ setting for greater customization.
# - **Consider Larger Earcups**: Offer a version with larger earcups to accommodate different head and ear sizes for greater comfort.
# - **Transition to USB-C Charging**: Adopt USB-C charging for improved speed, durability, and compatibility.
# - **Streamline Carrying Case**: Design a more compact and streamlined carrying case for better portability and ease of packing.
#
#
# ## Marketing Strategies
# To enhance consumer perception and satisfaction, the following marketing strategies are recommended, each aligned with insights derived from the analysis:
#
# - **Leverage Strong Customer Base:**: With a notable number of 4- and 5-star reviews, actively encourage satisfied customers to share their positive experiences through testimonials and social media. Highlight these reviews in marketing materials to build credibility and attract new customers.
#
# - **Targeted Campaigns**: Given the emphasis on sound quality in positive reviews, create targeted marketing campaigns that appeal to younger demographics and music enthusiasts. Focus on the superior audio experience, particularly for bass-heavy genres, to attract potential buyers.
#
# - **Promotional Offers:** The analysis indicated that price sensitivity is a concern for some consumers. Implement targeted promotional offers during peak shopping seasons to incentivize purchases, particularly for new customers looking for value.
#
# *(**Note:**) This was analyzed from text analysis of review content as there was no seperate column for price of each product*
#
# - **User Feedback Integration:** Recognizing the frustration regarding certain product features, such as noise cancellation and touch controls, actively seek and incorporate user feedback into marketing strategies. This demonstrates a commitment to improving customer satisfaction and responsiveness to consumer needs, reinforcing brand loyalty.
#
# ## Future Research
# Future research could explore the following areas to further enhance the analysis:
# - **Consumer Preference Studies**: Conduct surveys to gather insights on consumer preferences regarding sound quality, noise cancellation, and design features across different demographics.
# - **Longitudinal Studies**: Carry out longitudinal studies to assess shifts in consumer perceptions and satisfaction over time, especially after implementing product improvements and marketing strategies.

# %% [markdown]
# #Section 8: Conclusion
#
# The analysis of consumer sentiment for **Beats Studio3 and its Competitors** revealed several key findings that have significant implications for the brand's strategy and future development.
#
# - **Strong Customer Loyalty:**
# The brand boasts a robust customer base, with a considerable number of **4-** and **5-star reviews** highlighting positive aspects such as **sound quality**, **comfort**, and **battery life**. This loyalty presents an opportunity for Beats to leverage satisfied customers in marketing campaigns, enhancing brand credibility and attracting new users.
#
# - **Mixed Feedback on Features:**
# Despite the overall positive sentiment, there are notable criticisms regarding **noise cancellation** and **touch controls**. These insights underscore the importance of addressing product weaknesses to improve customer satisfaction and retain competitive advantage against rivals like **Sony** and **Bose**.
#
# - **Market Positioning and Competition:**
# The comparative analysis highlighted the intense competition within the **premium headphone market**. Competitors like **Sony** and **Bose** consistently innovate, which necessitates that Beats continues to enhance its product offerings and marketing strategies to maintain relevance and market share.
#
# Reflecting on the project, it has contributed to a deeper understanding of consumer sentiment regarding **Beats Studio3**, providing actionable insights for marketing and product development. The analysis not only illuminates the strengths and weaknesses of the Beats product line but also offers a strategic framework for future growth. By focusing on customer feedback, market trends, and competitive dynamics, Beats can enhance its position as a leading player in the audio market, ensuring continued success and consumer satisfaction.
